# %% [markdown]
# **Imports**

# %%
import pandas as pd
import numpy as np
import networkx as nx
import zlib
import pickle
import os
import matplotlib.pyplot as plt
from itertools import combinations
import sys
import math
from collections import Counter
from scipy.stats import zscore
import json
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler


compressed_sizes = {}

# %% [markdown]
# **Load dataset**

# %%
def load_dataset(file_path):
    with open(file_path, 'r') as f:
        data = [json.loads(line) for line in f]
    df = pd.DataFrame(data)
    return df

# %% [markdown]
# **Dictionary with pre-computed values**

# %%
def compute_compressed_sizes(user_ratings):
    
    for user, ratings in user_ratings.items():
        u_string = "".join(f"{k}:{v} " for k, v in sorted(ratings.items()))
        compressed_sizes[u_string] = len(zlib.compress(u_string.encode()))
    
    return compressed_sizes

# %% [markdown]
# **Similarities**

# %%
def linear_similarity(ratings_u, ratings_v):
    common_items = set(ratings_u.keys()).intersection(set(ratings_v.keys()))
    if not common_items:
        return 0  # If no common items, similarity is 0

    diff_sum = sum(abs(ratings_u[i] - ratings_v[i]) for i in common_items)
    ls_value = 1 - (diff_sum / len(common_items))
    return max(0, ls_value)  # Ensure similarity is non-negative

# Compression Similarity with precomputed sizes
def compression_similarity(ratings_u, ratings_v):
    u_string = "".join(f"{k}:{v} " for k, v in sorted(ratings_u.items()))
    v_string = "".join(f"{k}:{v} " for k, v in sorted(ratings_v.items()))
    c_uv = len(zlib.compress((u_string + v_string).encode()))
    c_u = compressed_sizes[u_string]
    c_v = compressed_sizes[v_string]
    return 1 - (c_uv - min(c_u, c_v)) / max(c_u, c_v)

# Kolmogorov Similarity with precomputed sizes
def kolmogorov_similarity(ratings_u, ratings_v):
    #ordena a priori os ratings dado por cada user
    u_string = "".join(f"{k}:{v} " for k, v in sorted(ratings_u.items()))
    v_string = "".join(f"{k}:{v} " for k, v in sorted(ratings_v.items()))
    c_u = compressed_sizes[u_string]
    c_v = compressed_sizes[v_string]
    return 1 / (1 + abs(c_u - c_v))

import math

def jaccard_similarity(ratings_u, ratings_v):
    """
    Computes the Jaccard Similarity between two users' rating sets.
    It considers only the presence of ratings, not their values.
    """
    items_u = set(ratings_u.keys())
    items_v = set(ratings_v.keys())
    
    intersection = items_u.intersection(items_v)
    union = items_u.union(items_v)
    
    if not union:
        return 0  # Avoid division by zero
    
    return len(intersection) / len(union)

def cosine_similarity(ratings_u, ratings_v):
    """
    Computes the Cosine Similarity between two users' rating vectors.
    """
    common_items = set(ratings_u.keys()).intersection(set(ratings_v.keys()))
    
    if not common_items:
        return 0  # If no common items, similarity is 0

    # Compute dot product and magnitudes
    dot_product = sum(ratings_u[i] * ratings_v[i] for i in common_items)
    magnitude_u = math.sqrt(sum(ratings_u[i] ** 2 for i in ratings_u))
    magnitude_v = math.sqrt(sum(ratings_v[i] ** 2 for i in ratings_v))
    
    if magnitude_u == 0 or magnitude_v == 0:
        return 0  # Avoid division by zero
    
    return dot_product / (magnitude_u * magnitude_v)

# %% [markdown]
# **Simlarity Matrix and graph**

# %%
# Compute user similarity matrix and construct graph (with precomputed sizes)
def compute_similarity_matrix(user_ratings, similarity_measure, compressed_sizes, similarity_threshold):
    similarity_graph = nx.Graph()

    # Step 1: Add all users as nodes (ensures isolated users are included)
    similarity_graph.add_nodes_from(user_ratings.keys())

    # Step 2: Compute pairwise similarities and add edges if similarity > 0.99
    for (u, v) in combinations(user_ratings.keys(), 2):
        sim = similarity_measure(user_ratings[u], user_ratings[v])
        if sim > similarity_threshold:
            similarity_graph.add_edge(u, v, weight=sim)

    return similarity_graph

# Detect user clusters from similarity graph
def detect_groups(similarity_graph,min_cluster_size):
    """ Detect user clusters from similarity graph and assign small clusters to a complementary cluster. """
    clusters = list(nx.connected_components(similarity_graph))
    complementary_cluster = set()
    filtered_clusters = []

    for cluster in clusters:
        if len(cluster) < min_cluster_size:
            complementary_cluster.update(cluster)  # Add small clusters to the complementary cluster
        else:
            filtered_clusters.append(cluster)  # Keep large clusters as they are

    if complementary_cluster:
        filtered_clusters.append(complementary_cluster)  # Add complementary cluster if it has users

    filtered_cluster_sizes = [len(group) for group in filtered_clusters]
    print("Number of clusters: ", len(filtered_clusters))
    print("complementary_cluster: ", len(complementary_cluster))
    mean_size = np.mean(filtered_cluster_sizes)
    std_size = np.std(filtered_cluster_sizes)
    z_score = (len(complementary_cluster) - mean_size) / std_size if std_size > 0 else float('inf')
    print("z_score: ", z_score)

    return filtered_clusters

# %% [markdown]
# **Reputation-based intra-clustering**

# %%
def compute_cluster_ratings(df, user_groups):
    """ Compute initial ratings per cluster based only on the items rated by at least 5 users in the cluster. """
    cluster_item_ratings = {}

    # Iterate through each user cluster
    for cluster_idx, user_set in enumerate(user_groups, start=1): 
        cluster_df = df[df["reviewerID"].isin(user_set)]  # Filter dataset to only include users in the cluster
        item_rating_counts = cluster_df["asin"].value_counts()  # Count ratings per item
        
        # Filter items that have at least x ratings
        #TODO
        valid_items = item_rating_counts[item_rating_counts >= 1].index  

        # Compute the mean only for valid items
        filtered_avg_ratings = cluster_df[cluster_df["asin"].isin(valid_items)].groupby("asin")["normalizedOverall"].mean().to_dict()

        cluster_item_ratings[cluster_idx] = filtered_avg_ratings

    return cluster_item_ratings

def refine_cluster_ratings(df, user_groups, cluster_item_ratings, threshold):
    """Refine cluster ratings by filtering out extreme user ratings until convergence."""
    refined_ratings = {}
    total_ratings_count = 0
    total_filtered_count = 0

    # Iterate through each user cluster
    for cluster_idx, user_set in enumerate(user_groups, start=1):
        if cluster_idx not in cluster_item_ratings:
            continue  # Skip clusters without precomputed ratings

        cluster_df = df[df["reviewerID"].isin(user_set)]  # Filter dataset to only include users in the cluster
        final_ratings = cluster_item_ratings[cluster_idx].copy()

        for item, initial_avg in final_ratings.items():
            item_ratings = cluster_df[cluster_df["asin"] == item][["reviewerID", "normalizedOverall"]].copy()

            total_ratings = len(item_ratings)
            total_ratings_count += total_ratings
            previous_avg = None
            current_avg = initial_avg
            filtered_count = 0

            while previous_avg is None or abs(current_avg - previous_avg) > 1e-6:  # Iterate until convergence
                previous_avg = current_avg
                lower_bound = current_avg - threshold
                upper_bound = current_avg + threshold

                # Identify ratings to be ignored in calculation but not deleted
                valid_ratings = item_ratings[(item_ratings["normalizedOverall"] >= lower_bound) & 
                                             (item_ratings["normalizedOverall"] <= upper_bound)]
                filtered_count = total_ratings - len(valid_ratings)
                total_filtered_count += filtered_count

                if valid_ratings.empty:
                    break  # Stop if no valid ratings remain

                new_avg = valid_ratings["normalizedOverall"].mean()
                current_avg = new_avg

            final_ratings[item] = current_avg

        refined_ratings[cluster_idx] = final_ratings

    print(f"Total Ratings: {total_ratings_count} | Total Filtered: {total_filtered_count}")
    return refined_ratings

def compute_weighted_average_cluster_ratings(cluster_item_ratings, user_groups):
    """Compute weighted average ratings for each item across clusters using cluster size as weight."""
    item_weighted_sums = {}
    item_total_weights = {}
    
    # Iterate over clusters and their item ratings
    for cluster_idx, item_ratings in cluster_item_ratings.items():
        cluster_size = len(user_groups[cluster_idx - 1])  # Cluster index is 1-based, user_groups is 0-based
        
        for item, rating in item_ratings.items():
            #intialize the item if it does not exist
            if item not in item_weighted_sums:
                item_weighted_sums[item] = 0
                item_total_weights[item] = 0
            
            # Add weighted contribution
            item_weighted_sums[item] += rating * cluster_size
            item_total_weights[item] += cluster_size
    
    # Compute weighted averages and round to the nearest decimal place
    weighted_averages = {item: round(item_weighted_sums[item] / item_total_weights[item], 1) for item in item_weighted_sums}
    
    return weighted_averages


def round_ratings_to_one_decimal(new_ratings):
    """Round all item ratings to the nearest one decimal place."""
    return {cluster: {item: round(rating, 1) for item, rating in items.items()} for cluster, items in new_ratings.items()}

# %% [markdown]
# **Plot Generation**

# %%
def plot_top_3_clusters(cluster_ratings):
    """Plot a bar chart showing the rating distribution for the three largest clusters with bins."""
    # Sort clusters by size (number of items rated) in descending order
    top_clusters = sorted(cluster_ratings.keys(), key=lambda c: len(cluster_ratings[c]), reverse=True)[:3]

    # Define bins from 0.1 to 1.0 (inclusive)
    bins = np.arange(0.05, 1.05, 0.1)  # Bin centers
    bin_labels = [round(b, 1) for b in np.arange(0.1, 1.1, 0.1)]  # Labels for x-axis

    plt.figure(figsize=(12, 5))

    # Adjust vertical position offset for each cluster
    vertical_offset = 0.0

    for cluster in top_clusters:
        # Flatten ratings in the cluster
        ratings = list(cluster_ratings[cluster].values())

        # Digitize ratings into bins
        bin_indices = np.digitize(ratings, bins, right=True)
        bin_counts = Counter(bin_indices)

        # Create an aligned count array
        counts = [bin_counts[i + 1] if i + 1 in bin_counts else 0 for i in range(len(bin_labels))]

        # Plot the bar chart for the cluster, adjusting the position of the bars
        plt.bar(bin_labels, counts, width=0.07, alpha=0.6, label=f'Cluster {cluster}', bottom=vertical_offset)

        # Add value labels with a vertical offset for readability
        for i, count in enumerate(counts):
            if count > 0:
                plt.text(bin_labels[i], count + vertical_offset + 0.5, str(count), ha='center', fontsize=10)

        # Update the vertical offset for the next cluster
        vertical_offset += max(counts) + 2  # Adjust the offset based on the max count in the current cluster

    plt.xlabel("Item Rating (Binned from 0.1 to 1.0)")
    plt.ylabel("Number of Items")
    plt.title("Jaccard 0.5 | reputation threshold 0.95")
    plt.xticks(bin_labels)
    plt.legend()
    plt.show()



def plot_weighted_average_distribution(weighted_average_dict):
    """Plot a bar chart showing the distribution of weighted average ratings with bins from 0.1 to 1.0."""
    # Flatten weighted averages
    ratings = list(weighted_average_dict.values())

    # Define bins from 0.1 to 1.0
    bins = np.arange(0.05, 1.05, 0.1)  # Bin centers
    bin_labels = [round(b, 1) for b in np.arange(0.1, 1.1, 0.1)]  # Labels for x-axis

    # Digitize ratings into bins
    bin_indices = np.digitize(ratings, bins, right=True)
    bin_counts = Counter(bin_indices)

    # Create an aligned count array
    counts = [bin_counts[i + 1] if i + 1 in bin_counts else 0 for i in range(len(bin_labels))]

    # Plot the bar chart
    plt.figure(figsize=(10, 5))
    plt.bar(bin_labels, counts, width=0.07, color='blue', alpha=0.7)

    # Add value labels
    for i, count in enumerate(counts):
        if count > 0:
            plt.text(bin_labels[i], count + 0.5, str(count), ha='center', fontsize=10)

    plt.xlabel("Weighted Average Rating (Binned from 0.1 to 1.0)")
    plt.ylabel("Number of Items")
    plt.title("Distribution of Weighted Average Ratings (Binned)")
    plt.xticks(bin_labels)
    plt.show()

# %% [markdown]
# **Main function**

# %%
# Main execution
file_path = "/home/martim/Desktop/tese/datasets/amazon_beauty/Luxury_Beauty_5_normalized.json"  #Replace with your dataset path
df = load_dataset(file_path)

#Prepare user ratings
user_ratings = {user: dict(zip(group["asin"], group["normalizedOverall"])) for user, group in df.groupby("reviewerID")}

print("\nuser_ratings: ", user_ratings)
# Compute or load compressed sizes
compressed_sizes = compute_compressed_sizes(user_ratings)
print("comprimido")
# Out:
# user_ratings:  {'A0488385844WNV2OWO9X': {'B0001EKVGS': 0.8, 'B0007ZG2DW': 1.0, 'B000CRQHNU': 1.0, 'B000GHVTN4': 1.0, 'B000GHXTPA': 1.0, 'B000YBNL2Y': 1.0, 'B001G9CJO4': 1.0, 'B0036G153G': 1.0, 'B0044KBZFQ': 1.0, 'B008MAPGEK': 1.0, 'B008MAUMEO': 1.0, 'B00IZO0LLG': 1.0, 'B00VV8S1GK': 1.0, 'B00F6XZNOO': 1.0}, 'A0916357J9P21ZUYUZO6': {'B00172BJ3W': 1.0, 'B00172O9NO': 0.4, 'B001VJVP0S': 1.0}, 'A0976794S8VOYNT78YEM': {'B0006PLMFQ': 1.0, 'B000J4FGAG': 1.0, 'B0058TE4WI': 1.0, 'B00699JDKY': 1.0, 'B007PORYUI': 1.0, 'B00B59AULY': 1.0, 'B00BXS9PFE': 1.0, 'B00DTH63P2': 1.0}, 'A1004703RC79J9': {'B000A5CPJ4': 0.8, 'B000WMWR1G': 1.0, 'B001G60EGW': 1.0, 'B002RSUPD0': 1.0, 'B0052H2JXW': 1.0, 'B006IQVFTA': 1.0, 'B00CUF3RZ8': 0.4, 'B00CUF51XO': 0.8, 'B00ET3D5VK': 0.8, 'B00I5K7XSY': 1.0, 'B00UGLH286': 0.8, 'B00UKLKNJC': 0.6, 'B00UKO5SG2': 1.0, 'B014R3FO92': 0.4, 'B01ELUGLUW': 0.8, 'B01ELWU4NU': 0.8, 'B01FTP9XH6': 0.8}, 'A100WO06OQR8BQ': {'B00014GT8W': 0.6, 'B0013J8ARW': 1.0, 'B0015ZC1CY': 1.0, 'B001EGP680': 0.2, 'B002WZJQLA': 1.0, 'B00CYHM7NU': 0.2, 'B00ES5KT54': 1.0, 'B00FQLKLP2': 1.0, 'B00H2VO6P0': 0.6, 'B00LIXT0M2': 0.6, 'B00M0V39VE': 0.8, 'B00M0V3D7Y': 0.6, 'B00MGSJG3G': 0.6, 'B00NEPFQPW': 1.0, 'B00NZ1FH86': 1.0, 'B00PSFLL3M': 0.2, 'B00ZL8YFSE': 1.0, 'B010NHCYHQ': 0.6, 'B01BY3T1JM': 0.6, 'B01CF4J540': 1.0, 'B01CP39FL4': 0.6, 'B01GDUM666': 0.6, 'B000LD3J3Q': 0.2, 'B00II27SSO': 1.0}, 'A100ZQDV7L8PVV': {'B0002CEIQ8': 0.8, 'B000OSADQE': 1.0, 'B00172LM8O': 1.0, 'B001NZ1OWO': 0.8, 'B008H6N7TU': 0.4, 'B00B95PWYE': 1.0, 'B018B2AN50': 1.0}, 'A102300ZYSDHRR': {'B0015Z90NC': 1.0, 'B0015ZC1FG': 1.0, 'B00172O9NO': 1.0, 'B002CMLHF6': 1.0}, 'A102866V814SOJ': {'B000GDJDPE': 0.4, 'B000VN8K2G': 0.4, 'B000WN417I': 0.4, 'B00A9OEJT0': 0.4}, 'A102V8N45CTOIC': {'B0006PLMFQ': 1.0, 'B000J4FGAG': 1.0, 'B0058TE4WI': 1.0, 'B00699JDKY': 1.0, 'B007PORYUI': 1.0, 'B00B59AULY': 1.0, 'B00BXS9PFE': 1.0, 'B00DTH63P2': 1.0}, 'A1047EDJ84IMAS': {'B000N2KWOY': 0.8, 'B0014TMHBG': 1.0, 'B003OYG18O': 1.0, 'B005NQRPFO': 1.0}, 'A107RJ8R12ERDP': {'B000HP5G70': 1.0, 'B000WN417I': 1.0, 'B005CBWYME': 1.0, 'B00UKLH4SU': 1.0}, 'A108XP24UESKSV': {'B00014GT8W': 0.6, 'B0010MGK6A': 1.0, 'B00FGB1J3K': 0.8, 'B012NSQIRA': 1.0, 'B016IXPWO6': 0.6, 'B000LZW5N4': 0.8}, 'A109L3WXD1SJFU': {'B0038CS02W': 0.6, 'B0038COKQ2': 0.6, 'B00B95PWYE': 0.8, 'B00TBJWR0M': 1.0, 'B01BTWDRN4': 0.8}, 'A10CGTF3GZ2V65': {'B0002ZW5UQ': 1.0, 'B000QGKQXO': 1.0, 'B0013U0EYI': 1.0, 'B019N8UNK6': 0.6}, 'A10H63KUGJEPAJ': {'B000ZOFUOC': 1.0, 'B001FNPJ5C': 0.8}, 'A10K606KWGOA2Y': {'B000068DWY': 1.0, 'B0009OAHWI': 1.0, 'B000OOSHAM': 1.0, 'B001KOTQQ4': 1.0}, 'A10NK3J44E66BN': {'B000Q384SQ': 1.0, 'B000YBNL2Y': 1.0, 'B0017SWIU4': 1.0, 'B001J3ISOM': 0.4, 'B001Q58FAK': 0.8, 'B00HEHRCZS': 0.4, 'B00I8NUF2O': 0.4}, 'A10QJ6CMP3UHC6': {'B000Q388UK': 0.6, 'B001QTLNK0': 1.0, 'B00396VE7U': 1.0, 'B003TY8UEC': 0.6}, 'A10S3PNZ5Y0FRT': {'B0002ZW5UQ': 0.6, 'B0013U0EYI': 0.6}, 'A10VTKMX0HUEJK': {'B0006PLMFQ': 1.0, 'B000J4FGAG': 1.0, 'B0058TE4WI': 1.0, 'B00699JDKY': 1.0, 'B007PORYUI': 1.0, 'B00B59AULY': 1.0, 'B00BXS9PFE': 1.0, 'B00DTH63P2': 1.0}, 'A10Y058K7B96C6': {'B002A9JR8U': 0.6, 'B00ET3D6JG': 0.8, 'B00ET86JSG': 0.6, 'B00NZ1FH86': 1.0, 'B01FMPRQFO': 0.8}, 'A10ZBR6O8S8OCY': {'B0002CEIQ8': 0.8, 'B0013B53DY': 1.0, 'B002WZJQLA': 0.8, 'B0038COKQ2': 0.8, 'B00CFS8YFI': 0.8, 'B00HM73LZA': 1.0, 'B00HSR0Q3Y': 0.8, 'B00J9POUBC': 0.8, 'B00M0V083Q': 0.8, 'B00RXZHZK8': 0.8, 'B00TK133U4': 0.8, 'B0185ZIU62': 0.8, 'B01CP39HMG': 0.8, 'B01HGSJPMW': 0.8, 'B0058YKIA0': 0.6, 'B015OVPG4E': 0.6}, 'A110KACX3W12L9': {'B0037MIMLW': 1.0, 'B003OGV7UO': 0.2, 'B004N2S2JM': 0.2, 'B00D13IM8U': 0.8, 'B00JIM55MY': 1.0, 'B01C68GAXE': 1.0, 'B007EZ0CC0': 1.0}, 'A110RS7QL8Q1UX': {'B0001XDTYA': 0.6, 'B00021AKJI': 1.0, 'B006IQVFTA': 1.0, 'B01A5OO0LU': 0.8, 'B01FMPRQFO': 1.0}, 'A111VACTMOWL5H': {'B000GSTHZU': 1.0, 'B000YBNL2Y': 1.0, 'B001J3ISOM': 0.4, 'B004SGZ610': 1.0}, 'A113DS2A66B9VJ': {'B0006PLMFQ': 0.8, 'B000J4FGAG': 0.8, 'B0058TE4WI': 0.8, 'B00699JDKY': 0.8, 'B007PORYUI': 0.8, 'B00B59A ...
# comprimido

# %% [markdown]
# **Clustering**

# %%
# Choose similarity measure: linear_similarity, compression_similarity, kolmogorov_similarity
similarity_graph = compute_similarity_matrix(user_ratings, jaccard_similarity, compressed_sizes, 0.5)

# Get threshold for complementary cluster
num_users = df["reviewerID"].nunique()
complementary_cluster_threshold = num_users * 0.01

# Detect user clusters from similarity graph
user_groups = detect_groups(similarity_graph, complementary_cluster_threshold)

# Print the number of detected clusters
print(f"User groups: {(user_groups)}")

print("number of user_groups: ", len(user_groups))

#count total number of elements in usergroups
total = 0
for group in user_groups:
    total += len(group)
print("total number of elements in usergroups: ", total)

#biggest user group, average size of user groups
biggest = 0
for group in user_groups:
    if len(group) > biggest:
        biggest = len(group)
print("biggest user group: ", biggest)

average = total / len(user_groups)
print("average size of user groups: ", average)
# Out:
# Number of clusters:  5
# complementary_cluster:  2928
# z_score:  1.9870748646255554
# User groups: [{'A2B7VGVN59XJUM', 'A1H055LCNXKT1J', 'A1TXHK8MONJHC3', 'ALJUE2EBH9XIA', 'A2UXU5DDCYN4GP', 'A5T9Z3JIUR0RO', 'ALBPPZ969I5CM', 'A1NH81HVJXIM05', 'A1A4YGDZRUFQFS', 'AU1I8VGB7D254', 'A1XQOQ0GWJP1X6', 'A3J1B9AQYC9ZM0', 'A2OD11BKV2YNED', 'A3LQ2OIJG9BO97', 'A2HX3MWQDOM5AZ', 'A2WCNWKJV9DQAB', 'A1STC2PCXN65A1', 'AP5TZGSMF73L', 'A27MGH8RM9WXT7', 'A1G4KDEM2V5376', 'A1E7428658LMTY', 'AZ0O1CT77N1W7', 'A2QVLWFBQ08FYC', 'A1ENECC591UAIC', 'AM0OKL6AFIBDX', 'A237XY0O6V3UE', 'A2UE27NXVYHIP9', 'ABOTQDXWRU51G', 'A3HLZAGW84MWLS', 'A9419F2N03T5B', 'A31I1YHJKPUCAI', 'A4L7ETIO4IDFC', 'A2R46TPY466FDC', 'A78Y9O0GSY28T', 'A3LOAIRUUNO5IX', 'A276HKHAM5VK53', 'ASB37ZYP0PZ0J', 'A2KRRIZVD7QEDG', 'ABU93V5LFXTV1', 'A1MFMWKPTDFZE8', 'A1HW72TSGGCGOZ', 'A7KDJ0MVYYRA0', 'A3NIHCBCOWK4X5', 'A2BRTCOIW7TDYK', 'A3E2U597OBS9ON', 'AL8FI5X2OD33S', 'A3T97RJ08ZQ0BT', 'AEMYLEFZCRX5S', 'A1UYMA2KBEZJAV', 'ASBKP2FY961VO', 'ABZB6K3IQMXZU', 'AZSYHIK3A3KWE', 'A67FOUJLCZPS3', 'A3BPZ2XFRLCD1S', 'A353BBCDJQP4A3', 'A2IYAPUAR0PTUD', 'AYVE4ULAGMVGT', 'A3CQVSKPTU3PJV', 'AO9G5HQYQHLHP', 'A1353000WAKP87', 'A1R2N7UH4YQTN', 'A1RVV44OXXTD0', 'A26AVD5D1SNXIN', 'A2AEHBRCY7G9HE', 'A25EMUVX5WMVZ1', 'A2P652CXM82IH6', 'A1EKCH0FI00Q1J', 'A3S7ZJ0I6KR5H3', 'A1HTD9BFY0Y557', 'A3JTUS0UZG6V9T', 'A3S3Y3HC9BVSMO', 'A1MUHMPF5XYTAP', 'ALWI22L1YH50U', 'A1YVUUHT093E0K', 'A2U64G6KP1ULRB', 'A2Q582Q4S2MUGM', 'A1M0VRITABSIQ6', 'A2A4IIRGAEXUXC', 'A1R3IUM1KVYK5I', 'AOUC76JLMBP3I', 'A1MU2YMN78CADQ', 'A1TZHV7ZF1BP4P', 'A35P9MY9132FNU', 'AQGQXINCTPYS5', 'A1VZHK5PZJP1YX', 'APJDB661HN4UR', 'A3IUPHLK5U0MVL', 'A3RDRB33M4U8ZH', 'A2KOVJ269YNR6M', 'A32SV7GY4ZEMX1', 'A2ZF5B40WVBD93', 'A1SW3YQTS0SWSR', 'A1BCRICL4UUBC6', 'A3B3XT2P0I34W4', 'A26X49ZG08Z1CI', 'A29D7CG7TLY35O', 'AP0O3EO7ALT63', 'A2N85D8FRR118S', 'A2F8X61SB7F73B', 'A2YUGPUW2HGNCU', 'A39X80RZSF8IYF', 'A1RXH3XWSYIB1M', 'A399EX3UULKLU2', 'AQ8Y0VADON6Z5', 'A1TV61AKAPGSMP', 'A2CY5UPGEPR12F', 'A2PP6U0R0FZUW6', 'A2CGZJXBGSBI0R', 'ADQXQ3AN16RCK', 'A1UFPZUUATIGXF', 'A3O4RA4POHFEIQ', 'A3GGOEX6SK1J71', 'A1B1J242B6OQK9', 'A3847X9XD27OSL', 'A2UI38UXH48SCX', 'A3P1GD23H8E2BY', 'A1WRTQBUNULI0A', 'A29H57JOW1ZB1Z', 'AE4AI4GHFW8PC', 'A1DULQKYC6EV1B', 'A25QIF834WW9GQ', 'A1QU1H8R28NIGX', 'A7QQCZK96JMS6', 'AY17MGNAV9K1J', 'AGV6KOEXODL1U', 'A2IOZ71FUD9024', 'AV3A66BTGK2G5', 'AANBV13XF1JD4', 'A3G9GVHBAHGMUI', 'A17JGEYNQRYMHE', 'AVIR4DIQYVIZC', 'A1BSIL9GW9FCR2', 'A3R7PGG5QMI6TI', 'A13ARKH8FCOFQ0', 'A23H193P451P74', 'AEMTSFFDU85KB', 'A2K7N4FBGEHVK9', 'A3KHWY7T46BBAP', 'A29DQ5N0LMVP3H', 'A3K9PKWXG2J873', 'A38YT9I8SQ20NI', 'A351804L86H9Z6', 'A3A0F30QQGL1EW', 'A2UISZV5CTD805', 'A2M51VLOW1V1JR', 'A3PFZA9XC59D2Z', 'A326ORFY46O7CX', 'A28TV838J24262', 'A2QB0TIWFCUYIL', 'A2YPX6VJN8LPQZ', 'AYR9VFT77U68X', 'A2QWJXBD0LB13A', 'A3V3Q2E70VWCD6', 'A0976794S8VOYNT78YEM', 'A2AGOAOL5NFEUP', 'AIC7VZ9VNYRHK', 'A2IBUK9XJOYRJW', 'A1X6ASXO8F7A9E', 'AIO4X9BRTWT9J', 'A1QAPTV4YS16N9', 'ATSFY4UITEOEJ', 'AU71YJNA3E3J1', 'A1FVWVS8CRIRBO', 'A2JPRGJ2GVDANZ', 'A2F239LT1G70GB', 'AAP42A9X4RFOL', 'A365807DF8EYTN', 'A21VLPGCRFH6OF', 'A221FPD86E5O87', 'AQ63ZV8M31WL3', 'A1X1ASMQZESS3Q', 'A2T0MNN392O3RY', 'A20RNDVGF6IOMQ', 'A2Q87SAW72XHBB', 'A16467WWAC2UNP', 'A3GJRZ7FN51LMK', 'A2K2XYGCMHNV8C', 'A3KUVPJHTGGLTB', 'A3LKPZO4ZSRC23', 'A9XJ6GVTNDF2X', 'A11F3YONMF67ML', 'A2H2K1FKI9COQ6', 'A2LOCTEN93UHSV', 'A1U5JW2BP2DXTZ', 'A31ZXB9VUW2HQP', 'A2H7UOR72X7F2G', 'A1LXM5PZZHTT6W', 'A2MWA7HFUXV8J8', 'A1ZQKZ1K54USYJ', 'A4OTYAYS5X61E', 'ASR3LGBNR6FSJ', 'AB9LV3BWK3O4K', 'A265TY8TEJ5N8G', 'A1SX73TKLN7DPH', 'A11UJ1CHEHNEGP', 'AL717X1GYM0JV', 'A1LRQWKGVXCJ7C', 'A1WOTG0N2J0ZZK', 'A3V8ZP41Z782M9', 'A3DHWMWIDS2XX5', 'A13V89Q8UQUKTQ', 'A3EJRWOYRI5N34', 'AFYLPYJ7AORLR', 'A38KYGR07SUF21', 'A2D9VVQFYQHMUU', 'A39LRXD7THXB4B', 'A13E7YU3XNRNL9', 'A26R3E15OMP52T', 'A319KAPLOSIDRU', 'A2FC7HQW52PHE1', 'A3DES8CHOO4UH0', 'A3F8A11FLWKOJS', 'A21BQ8UAD3D6VJ', 'A1SV13PG7D7SJX', 'A39ECS1S0CJ0X9', 'A31H39YEJEIVHX', 'APYAPE8TWN8XC', 'A2W8NQPP91206I', 'A239ER4X93L28K', 'A2ATHY1VLNANIL', 'A1DCY7A46MU8F4', 'AC7UJP1OQ1T2A', 'A18712EH6VCYFP', 'AUDPHTF2KH1JS', 'A2L ...
# number of user_groups:  5
# total number of elements in usergroups:  3819
# biggest user group:  2928
# average size of user groups:  763.8

# %%
df = pd.DataFrame(user_ratings).T.fillna(0)  # Fill missing values with 0

scaler = StandardScaler()
normalized_data = scaler.fit_transform(df)

k = 5  # Number of clusters (choose based on Elbow Method)
kmeans = KMeans(n_clusters=k, random_state=42)
clusters = kmeans.fit_predict(df)

# Assign cluster labels to users
df["cluster"] = clusters

cluster_map = {}
for user, cluster in zip(df.index, clusters):
    cluster_map.setdefault(cluster, []).append(user)

# Print the resulting cluster dictionary
print(cluster_map)
# Out:
# {0: ['A0488385844WNV2OWO9X', 'A0916357J9P21ZUYUZO6', 'A0976794S8VOYNT78YEM', 'A1004703RC79J9', 'A100WO06OQR8BQ', 'A100ZQDV7L8PVV', 'A102300ZYSDHRR', 'A102866V814SOJ', 'A102V8N45CTOIC', 'A1047EDJ84IMAS', 'A107RJ8R12ERDP', 'A108XP24UESKSV', 'A109L3WXD1SJFU', 'A10CGTF3GZ2V65', 'A10H63KUGJEPAJ', 'A10K606KWGOA2Y', 'A10NK3J44E66BN', 'A10QJ6CMP3UHC6', 'A10S3PNZ5Y0FRT', 'A10VTKMX0HUEJK', 'A10Y058K7B96C6', 'A10ZBR6O8S8OCY', 'A110KACX3W12L9', 'A110RS7QL8Q1UX', 'A111VACTMOWL5H', 'A113DS2A66B9VJ', 'A1143YEAZYMYHJ', 'A11440ZB6FEAKF', 'A117FS98WND9A3', 'A117XUS2KI1M04', 'A1190GQQ1BTICP', 'A11A05XL3VUOUQ', 'A11AP4QERYPCLK', 'A11B61QBGHLQDN', 'A11CV6M1H8S1EC', 'A11EQENJJRH8X6', 'A11F3YONMF67ML', 'A11F5KW6QXHL8L', 'A11FX8HL2ANK6T', 'A11GP02YZJBGG3', 'A11IKWE7B29TOJ', 'A11J81ZI9KAERU', 'A11JWVCT7N93NH', 'A11JXAJHP7KESY', 'A11K70GWSB7A5Z', 'A11LI37SHY97N', 'A11LNPG39A2ZV4', 'A11LZPM3Z86VWM', 'A11N2I11HJBD3E', 'A11OTLEDSW8ZXD', 'A11UJ1CHEHNEGP', 'A11UNM6QZ3XTZH', 'A11X1WHC7P6DGN', 'A11XLS2X7AO7PQ', 'A11YA52GQ0D6B6', 'A11YC63APLB2K9', 'A11Z3ANM4PQFMH', 'A122SFGLAHQLSJ', 'A1278GKNIB8UZ', 'A12C1OTJ37UUG7', 'A12DQZKRKTNF5E', 'A12E0Y0J6584RT', 'A12ENBT314RFXR', 'A12GK5JUYAV0HM', 'A12LOSDZX5869M', 'A12PH6L5QSVTYN', 'A12S8UQEIPZJKE', 'A12UB42W3M4FTS', 'A12V2M84DUFGL5', 'A12X7K54734QXE', 'A12YPN6IFWKN93', 'A12ZFSESFYJF2G', 'A1307TZ17X6SD2', 'A133L22TAC5TA9', 'A1353000WAKP87', 'A1382NUB0AKHTK', 'A13ARKH8FCOFQ0', 'A13BQX5F2A0CQF', 'A13E51ZEL1ZU7M', 'A13E7YU3XNRNL9', 'A13EHOQ40ARXDI', 'A13FIFP73X0GTR', 'A13GZCHAMKWYBT', 'A13H5US9Z7L9M7', 'A13HG7EAUWRYPP', 'A13J2PGKNMJG1K', 'A13JH2NRRR2NF6', 'A13KW5I9IHQ039', 'A13M9XSQ4O6NLY', 'A13MKSASQ6YWL7', 'A13NJZ1M018A7C', 'A13OUY99ND8NWI', 'A13QN9DLFWOHRN', 'A13RTK1873ZLFS', 'A13RTN901YNT7S', 'A13TAZK9Q95A35', 'A13V89Q8UQUKTQ', 'A13VL2XSHUWRTH', 'A13WEKTB63G78Y', 'A13X7XBBT1DN8U', 'A140ICK18NAAYR', 'A141R97FHSSUQ0', 'A141W8WHW9AC3H', 'A1437CAM9CNC1E', 'A14638TGYH7GD9', 'A148RQ0M580F8V', 'A14ASZDYCXUTI0', 'A14CCDURTA6ZMO', 'A14CXGHPONCD41', 'A14E1OFMG2FCZG', 'A14E7LZASLSX36', 'A14EA9WQPSOKMF', 'A14EPTYN50XSZV', 'A14IW8KL9JGS2H', 'A14IW8OQ1BS0OB', 'A14JDMEHQJRR3T', 'A14L2638XC00EZ', 'A14MSHFCXPARFS', 'A14NA0W8ESGDSI', 'A14NOLEEBDE2Y9', 'A14OV0HV6TRWFF', 'A14T4JDOMP7U9G', 'A14UD72N0L7RXT', 'A14V1KIQU0U4RV', 'A14ZXOYLX5LVH3', 'A1501C38OCSEMA', 'A1520O7UE0HDWI', 'A152TZLTJNQNBA', 'A154UC6EHTSXAC', 'A1564JVII4G8PB', 'A1575JUI75IY6T', 'A1575LB2RX92AW', 'A157UIVPN0NYNN', 'A1592Z8VTIL15Q', 'A159B1DZK24I3K', 'A15DEX5N1ZG95W', 'A15DH2ICDH1MJN', 'A15DKVM598GQKS', 'A15EREQSX2JBZH', 'A15HBO5EBRDGTQ', 'A15I2N31VCSBH6', 'A15KYC62I1EIAC', 'A15OAS39003U5R', 'A15OVM8JWXHVNF', 'A15PUBCS4N4G60', 'A15Q9YEG1XPEJN', 'A15R5T6T1TBSJX', 'A15S9RB0R1D15Y', 'A15T487HNTIOF7', 'A15T9G38F589KM', 'A15TM51XDDGPZ7', 'A15TT902PJFJ9C', 'A15WSZ11YEOKMU', 'A15X5I17CU4I2H', 'A1606LA683WZZU', 'A16467WWAC2UNP', 'A167ABU99FT4OC', 'A168SCI9KUMXD9', 'A169O5HY388HQN', 'A169OY1LOA0RX3', 'A16AXQ11SZA8SQ', 'A16BMPHP8GSIWS', 'A16CJ83ZHH89MQ', 'A16EEZCPYPEUHF', 'A16G8LLLHG0SNI', 'A16GWMW2GI8XUJ', 'A16NRV54CGOO69', 'A16PUD6V3KAZ0Q', 'A16QJ424UMZVWR', 'A16QODENBJVUI1', 'A16R6O1P7TMF9N', 'A16UMY0X6X7R03', 'A16UO065RCHCGW', 'A16V9XOFCL1TJ5', 'A16VM71BLBCMMK', 'A16WPA6JV83YXT', 'A16YMCFWGSFGS9', 'A16YU3GRGCD95S', 'A16Z2OECAUX8Z4', 'A16ZKKJHDWC44Y', 'A171ITAMNOUCY8', 'A1739RDYJNA6HT', 'A173YMJ9XFVRSY', 'A175WOXLHJ9N5G', 'A17771LTRWSKQ5', 'A179D8LPMCGP9W', 'A17AHTCKJ4SUT0', 'A17BUSL163PDGQ', 'A17CBPANJ3G5T9', 'A17D2CT8TAPMSG', 'A17E3NBADNTI3X', 'A17GI2HXKPXHSU', 'A17HVSEZB2PDQK', 'A17ICF11AQU9B3', 'A17IS2KTMUBJ52', 'A17JGEYNQRYMHE', 'A17JOFI9IDPSES', 'A17O2BER0O0P1K', 'A17O7FT0JX5B72', 'A17PDN3EW1F05G', 'A17PDSMPB7HLYZ', 'A17RWH6Y9DDYBR', 'A17SNTLDQWMULL', 'A17TASZJT6Y39D', 'A17WBBVKJH3F3C', 'A17Y6O6I2O5S6P', 'A17ZH0JUGO72PH', 'A1806K4AD7LM0W', 'A181TIQPGSTYH6', 'A1832G4GPDDPOH', 'A184XTCFOCLX7Y', 'A18585LWC6ABKV', 'A186H8P2CH4ORG', 'A18712EH6VCYFP', 'A18B1KJJ14O0TO', 'A18CX8MRLUE35E', 'A18DHHHRTNZAM0', 'A18DNSET02IWGK', 'A18ECVX2RJ7HUE', 'A18G130R7K8W07', 'A18GJ9MYYO6GCQ', ' ...

# %% [markdown]
# **Ranking computation**

# %%
# Assuming user_groups is already defined
cluster_item_ratings = compute_cluster_ratings(df, user_groups)  # Step 1: Compute initial ratings

print("cluster_item_ratings: ", cluster_item_ratings)

refined_cluster_ratings = refine_cluster_ratings(df, user_groups, cluster_item_ratings, threshold=0.3)

weighted_average_dict = compute_weighted_average_cluster_ratings(refined_cluster_ratings, user_groups)

# round all clusters values 
rounded_ratings = round_ratings_to_one_decimal(refined_cluster_ratings)

print("rounded_ratings: ", rounded_ratings)
print("len(rounded_ratings): ", len(rounded_ratings))

plot_top_3_clusters(rounded_ratings)  # Use actual dictionary
plot_weighted_average_distribution(weighted_average_dict)  # Use actual computed weighted averages
# Out:
# cluster_item_ratings:  {1: {'B000142FVW': 0.9333333333333332, 'B00014340I': 1.0, 'B0001435D4': 0.8666666666666667, 'B0001EL5R2': 1.0, 'B0002NXRVY': 0.6, 'B0006PJRRG': 1.0, 'B0006PJRVM': 1.0, 'B0006PLMFQ': 0.8554585152838429, 'B0009EXM52': 1.0, 'B0009OAHWI': 1.0, 'B0009OAI40': 1.0, 'B000ASDX3S': 1.0, 'B000BGRC18': 1.0, 'B000CNTT9I': 1.0, 'B000J4FGAG': 0.8545054945054945, 'B000J4IE32': 0.8571428571428571, 'B000MEKG30': 1.0, 'B000MIH34Q': 1.0, 'B000N8CN4U': 1.0, 'B000NG80GM': 0.9333333333333332, 'B000NGI4QI': 0.6, 'B000NW4LDW': 1.0, 'B000PHKE0O': 0.6, 'B000PHTC20': 1.0, 'B000PZ8E62': 0.9, 'B000PZA2KS': 0.86, 'B000Q2Y062': 1.0, 'B000R92XHM': 0.8, 'B000SWY05Q': 0.8, 'B000SX3380': 0.8, 'B0015VP9CW': 0.8666666666666667, 'B0016J5TZK': 1.0, 'B001782ONU': 1.0, 'B0019IVEEI': 1.0, 'B001B271Q2': 0.8, 'B001DTZK0C': 1.0, 'B001O51GUI': 1.0, 'B001QOVUR6': 0.8, 'B001QRG190': 1.0, 'B001T0HHAG': 0.6, 'B001T0HHDS': 0.8, 'B001UHN0I6': 1.0, 'B00203SE2G': 0.6, 'B00265YNFK': 0.4, 'B002K6AHQY': 1.0, 'B002P3L99G': 1.0, 'B0031NNE56': 0.2, 'B00351VOUQ': 0.6, 'B00396VE7U': 1.0, 'B003CFB39C': 0.8, 'B003KW8V7E': 1.0, 'B003ZW2M5Q': 1.0, 'B004UQHJ7M': 0.5, 'B004XTX0VA': 1.0, 'B004YVDM2Y': 1.0, 'B00535OW6A': 0.8, 'B0058TE4WI': 0.8545054945054945, 'B005DUA5BG': 1.0, 'B00699JDKY': 0.8541850220264318, 'B006FXKP0Q': 1.0, 'B007PCB5OQ': 1.0, 'B007PORYUI': 0.8545054945054945, 'B007ZUGBLA': 1.0, 'B009043PEA': 1.0, 'B00992S5D4': 1.0, 'B00AWK6MF0': 0.9, 'B00B59AULY': 0.8545054945054945, 'B00BDJ0LX8': 1.0, 'B00BXS9PFE': 0.8536697247706422, 'B00CLIC7E6': 1.0, 'B00D13IM8U': 1.0, 'B00DTH63P2': 0.8536697247706422, 'B00EJ9Z6KW': 0.6, 'B00EU6NK66': 1.0, 'B00FRRVXLQ': 1.0, 'B00JFVG3E2': 0.2, 'B00JIM55MY': 0.8, 'B00KYAYL2E': 1.0, 'B00UI3OLZE': 1.0, 'B00V6R32BA': 1.0, 'B00YFTOET0': 0.2, 'B011CWNV1O': 1.0, 'B012TVK2RI': 1.0, 'B01DQG3DFI': 1.0}, 2: {'B00005V50B': 1.0, 'B0001Z66UM': 0.8307692307692307, 'B0002EBI82': 0.6153846153846154, 'B0002RI2PG': 0.9, 'B0002ZW5UQ': 0.88, 'B0007M11XQ': 1.0, 'B0009DVDTU': 0.4, 'B0009STDD8': 1.0, 'B000EMDK2Y': 1.0, 'B000GAO1PE': 1.0, 'B000H9C1UG': 1.0, 'B000MIF2S0': 0.2, 'B000PH8KDW': 0.8, 'B000PZA2KS': 0.6, 'B000QGKQXO': 0.6702702702702703, 'B000R94SMU': 1.0, 'B000RG8D6A': 0.2, 'B000SX3380': 0.4, 'B000VTRJTU': 0.4, 'B000WN417I': 1.0, 'B000Z657ZW': 1.0, 'B0010P6D28': 0.5599999999999999, 'B00110S21M': 1.0, 'B0013U0EYI': 0.88, 'B00158UZA6': 1.0, 'B00172O9NO': 0.7, 'B00176B8BG': 0.9, 'B00176B9JC': 1.0, 'B001G60EGW': 1.0, 'B001I6PTQA': 1.0, 'B001NJGARY': 1.0, 'B001W12MQ6': 1.0, 'B00265YNFK': 0.8, 'B0031NNE56': 0.7333333333333334, 'B00371C002': 0.8, 'B003CR4KRM': 1.0, 'B003WOU9DE': 0.2, 'B004W55086': 1.0, 'B004XBDPN6': 0.9333333333333332, 'B005VQZ09O': 0.7666666666666666, 'B006IYRUUU': 1.0, 'B007P0MO2U': 0.5333333333333333, 'B00846IUA4': 0.8, 'B00992S5D4': 0.6, 'B00DHOROQ4': 0.6, 'B00DY68AC2': 1.0, 'B00EOBAY3Y': 0.8, 'B00FW6O5FI': 1.0, 'B00JFWA1Q2': 0.8, 'B00QA29O2C': 1.0, 'B00VT144DS': 0.76, 'B019N8UNK6': 0.6}, 3: {'B00014351Q': 1.0, 'B0001Z66UM': 1.0, 'B00021CDQ6': 1.0, 'B00021EA9Y': 1.0, 'B0002L93N2': 1.0, 'B0006PKIQA': 0.6, 'B0007WX0EY': 1.0, 'B000ASDGK8': 0.9, 'B000BIPMC2': 1.0, 'B000BX1Z00': 1.0, 'B000GI3U6C': 1.0, 'B000IIA5UO': 0.8400000000000001, 'B000NGLR8A': 1.0, 'B000PZA2KS': 1.0, 'B000R92XHM': 1.0, 'B000WT9VTA': 1.0, 'B000YJ3UEK': 0.8, 'B00110U75Q': 1.0, 'B0013LZHUS': 0.6, 'B0015VP9CW': 0.6666666666666666, 'B0015ZC1FG': 1.0, 'B0016LTZD0': 1.0, 'B0016LXK6I': 1.0, 'B00172PC3A': 1.0, 'B00176GSEI': 0.8400000000000001, 'B00176SJPY': 0.8, 'B0017SWIU4': 1.0, 'B001AO0WCG': 0.9, 'B001NJGARY': 1.0, 'B001T0HHDS': 1.0, 'B001UHN0I6': 0.9, 'B00203Q9B4': 1.0, 'B002CML1XE': 1.0, 'B002D48R5G': 1.0, 'B002K6AHQY': 0.8408163265306123, 'B002LE54P4': 1.0, 'B002QG6P9G': 1.0, 'B002XOA16E': 1.0, 'B0031NNE56': 1.0, 'B0037MIMLW': 1.0, 'B00396VE7U': 0.8, 'B003OGV7UO': 0.9200561009817672, 'B004DQ0D1I': 1.0, 'B004J0XOTQ': 0.9733333333333333, 'B004JIDUWE': 1.0, 'B004LEKKZQ': 0.9, 'B004LEMWGG': 0.9777777777777779, 'B004LFUQDG': 0.9333333333333332, 'B004N2S2JM': 0.92005610098 ...
# Total Ratings: 34278 | Total Filtered: 8649
# rounded_ratings:  {1: {'B000142FVW': 1.0, 'B00014340I': 1.0, 'B0001435D4': 0.9, 'B0001EL5R2': 1.0, 'B0002NXRVY': 0.6, 'B0006PJRRG': 1.0, 'B0006PJRVM': 1.0, 'B0006PLMFQ': 1.0, 'B0009EXM52': 1.0, 'B0009OAHWI': 1.0, 'B0009OAI40': 1.0, 'B000ASDX3S': 1.0, 'B000BGRC18': 1.0, 'B000CNTT9I': 1.0, 'B000J4FGAG': 1.0, 'B000J4IE32': 0.9, 'B000MEKG30': 1.0, 'B000MIH34Q': 1.0, 'B000N8CN4U': 1.0, 'B000NG80GM': 1.0, 'B000NGI4QI': 0.6, 'B000NW4LDW': 1.0, 'B000PHKE0O': 0.6, 'B000PHTC20': 1.0, 'B000PZ8E62': 0.9, 'B000PZA2KS': 1.0, 'B000Q2Y062': 1.0, 'B000R92XHM': 0.8, 'B000SWY05Q': 0.8, 'B000SX3380': 0.8, 'B0015VP9CW': 0.9, 'B0016J5TZK': 1.0, 'B001782ONU': 1.0, 'B0019IVEEI': 1.0, 'B001B271Q2': 0.8, 'B001DTZK0C': 1.0, 'B001O51GUI': 1.0, 'B001QOVUR6': 0.8, 'B001QRG190': 1.0, 'B001T0HHAG': 0.6, 'B001T0HHDS': 0.8, 'B001UHN0I6': 1.0, 'B00203SE2G': 0.6, 'B00265YNFK': 0.4, 'B002K6AHQY': 1.0, 'B002P3L99G': 1.0, 'B0031NNE56': 0.2, 'B00351VOUQ': 0.6, 'B00396VE7U': 1.0, 'B003CFB39C': 0.8, 'B003KW8V7E': 1.0, 'B003ZW2M5Q': 1.0, 'B004UQHJ7M': 0.5, 'B004XTX0VA': 1.0, 'B004YVDM2Y': 1.0, 'B00535OW6A': 0.8, 'B0058TE4WI': 1.0, 'B005DUA5BG': 1.0, 'B00699JDKY': 1.0, 'B006FXKP0Q': 1.0, 'B007PCB5OQ': 1.0, 'B007PORYUI': 1.0, 'B007ZUGBLA': 1.0, 'B009043PEA': 1.0, 'B00992S5D4': 1.0, 'B00AWK6MF0': 0.9, 'B00B59AULY': 1.0, 'B00BDJ0LX8': 1.0, 'B00BXS9PFE': 1.0, 'B00CLIC7E6': 1.0, 'B00D13IM8U': 1.0, 'B00DTH63P2': 1.0, 'B00EJ9Z6KW': 0.6, 'B00EU6NK66': 1.0, 'B00FRRVXLQ': 1.0, 'B00JFVG3E2': 0.2, 'B00JIM55MY': 0.8, 'B00KYAYL2E': 1.0, 'B00UI3OLZE': 1.0, 'B00V6R32BA': 1.0, 'B00YFTOET0': 0.2, 'B011CWNV1O': 1.0, 'B012TVK2RI': 1.0, 'B01DQG3DFI': 1.0}, 2: {'B00005V50B': 1.0, 'B0001Z66UM': 1.0, 'B0002EBI82': 0.6, 'B0002RI2PG': 0.9, 'B0002ZW5UQ': 1.0, 'B0007M11XQ': 1.0, 'B0009DVDTU': 0.4, 'B0009STDD8': 1.0, 'B000EMDK2Y': 1.0, 'B000GAO1PE': 1.0, 'B000H9C1UG': 1.0, 'B000MIF2S0': 0.2, 'B000PH8KDW': 0.8, 'B000PZA2KS': 0.6, 'B000QGKQXO': 0.6, 'B000R94SMU': 1.0, 'B000RG8D6A': 0.2, 'B000SX3380': 0.4, 'B000VTRJTU': 0.4, 'B000WN417I': 1.0, 'B000Z657ZW': 1.0, 'B0010P6D28': 0.5, 'B00110S21M': 1.0, 'B0013U0EYI': 1.0, 'B00158UZA6': 1.0, 'B00172O9NO': 0.7, 'B00176B8BG': 0.9, 'B00176B9JC': 1.0, 'B001G60EGW': 1.0, 'B001I6PTQA': 1.0, 'B001NJGARY': 1.0, 'B001W12MQ6': 1.0, 'B00265YNFK': 0.8, 'B0031NNE56': 1.0, 'B00371C002': 0.8, 'B003CR4KRM': 1.0, 'B003WOU9DE': 0.2, 'B004W55086': 1.0, 'B004XBDPN6': 1.0, 'B005VQZ09O': 0.9, 'B006IYRUUU': 1.0, 'B007P0MO2U': 0.7, 'B00846IUA4': 0.8, 'B00992S5D4': 0.6, 'B00DHOROQ4': 0.6, 'B00DY68AC2': 1.0, 'B00EOBAY3Y': 0.8, 'B00FW6O5FI': 1.0, 'B00JFWA1Q2': 0.8, 'B00QA29O2C': 1.0, 'B00VT144DS': 0.9, 'B019N8UNK6': 0.6}, 3: {'B00014351Q': 1.0, 'B0001Z66UM': 1.0, 'B00021CDQ6': 1.0, 'B00021EA9Y': 1.0, 'B0002L93N2': 1.0, 'B0006PKIQA': 0.6, 'B0007WX0EY': 1.0, 'B000ASDGK8': 0.9, 'B000BIPMC2': 1.0, 'B000BX1Z00': 1.0, 'B000GI3U6C': 1.0, 'B000IIA5UO': 0.8, 'B000NGLR8A': 1.0, 'B000PZA2KS': 1.0, 'B000R92XHM': 1.0, 'B000WT9VTA': 1.0, 'B000YJ3UEK': 0.8, 'B00110U75Q': 1.0, 'B0013LZHUS': 0.6, 'B0015VP9CW': 0.5, 'B0015ZC1FG': 1.0, 'B0016LTZD0': 1.0, 'B0016LXK6I': 1.0, 'B00172PC3A': 1.0, 'B00176GSEI': 0.8, 'B00176SJPY': 0.8, 'B0017SWIU4': 1.0, 'B001AO0WCG': 0.9, 'B001NJGARY': 1.0, 'B001T0HHDS': 1.0, 'B001UHN0I6': 0.9, 'B00203Q9B4': 1.0, 'B002CML1XE': 1.0, 'B002D48R5G': 1.0, 'B002K6AHQY': 1.0, 'B002LE54P4': 1.0, 'B002QG6P9G': 1.0, 'B002XOA16E': 1.0, 'B0031NNE56': 1.0, 'B0037MIMLW': 1.0, 'B00396VE7U': 0.8, 'B003OGV7UO': 1.0, 'B004DQ0D1I': 1.0, 'B004J0XOTQ': 1.0, 'B004JIDUWE': 1.0, 'B004LEKKZQ': 1.0, 'B004LEMWGG': 1.0, 'B004LFUQDG': 1.0, 'B004N2S2JM': 1.0, 'B004N2SQUC': 1.0, 'B004SY3X3A': 1.0, 'B004YVDM2Y': 0.6, 'B005DYITD8': 1.0, 'B005G5FN2E': 1.0, 'B0065I8MC4': 1.0, 'B007AO3LJG': 1.0, 'B007EZ0CC0': 1.0, 'B007NPX4LM': 1.0, 'B007P0MO2U': 1.0, 'B007ZUGBLA': 1.0, 'B00A87CW0G': 1.0, 'B00AAR9I60': 1.0, 'B00AAV845M': 1.0, 'B00ALHISAQ': 0.8, 'B00AWK6MF0': 1.0, 'B00BPJ18DS': 1.0, 'B00CNE2GOO': 0.8, 'B00CNEADZ8': 1.0, 'B00CNEBSKM': 0.7, 'B00CNFZ9ZQ': 1.0, 'B00CNG2MGY': 0.8, 'B00D13IM8U': 1.0, 'B00EFGDYZS': 1 ...
# len(rounded_ratings):  5
